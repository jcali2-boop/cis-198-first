# %% [markdown]
# <a href="https://colab.research.google.com/github/jcali2-boop/cis-198-first/blob/main/cis198_Creating_a_github_website_with_markdown.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# *   google search
# *   ask LLm

# %% [markdown]
# ###github notes
#
# Key terms:
# * **repository**-a container holding all **commited** files and folders.
# * **commite**-saving a file in a repository.
# * **git**-version control program.
# * **github . com**-a online company(website)providing a place for users to save their website.
