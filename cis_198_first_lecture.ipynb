# %% [markdown]
# <a href="https://colab.research.google.com/github/jcali2-boop/cis-198-first/blob/main/cis_198_first_lecture.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('hello world')
# Out:
# hello world

# %% [markdown]
# ##create song using chat gpt
# output:
# [verse 1]
# In O’Shea Hall where the bright screens glow,
# Intro to Computer Science — time to learn and grow,
# Professor Ty’s at the front breaking code down right,
# Structured programming all day and night.
# [verse 2]
# Sophie’s typing fast, Andrew’s debugging strong,
# Hannah finds the errors before they go wrong,
# Julian’s got logic, Joe’s in the zone,
# Cue cracking problems like a coding pro.
# [bridge]
# Loops and conditions, functions that flow,
# Building up programs line by line we go,
# From simple commands to projects that shine,
# This class is the future — one code at a time.
# [final chorus]
# Yeah we’re learning together, no fear no stress,
# In Intro to CS we’re aiming for success,
# At Niagara Uni where dreams take flight,
# In O’Shea Hall coding into the night 🎤💻

# %% [markdown]
# ### markdown basics
# --------------------------------
# ###end a line with two spaces to create a new line###
# *italic*
# *bold*
# bulleted list
# .I
# .like
# .computers

# %% [markdown]
# **How to make a table**
# [Name][Major]
# [-------]-------]
# [monte]'Computer science']

# %% [markdown]
#  <p style='font-size:50px;'<

# %%
# %%HTML
# <p style="font-size: 50px">Hello world in Big font</p>
# Out:
# <p style="font-size: 50px">Hello world in Big font</p>
